# %% [markdown]
# # Chapter 8: Functions

# %% [markdown]
# ### 8-1. Message
#
# Write a function called `display_message()` that prints one sentence telling everyone what you are learning about in this chapter. Call the function, and make sure the message displays correctly.

# %%
def display_message():
    print("I am learning about functions in Python!")

display_message()

# %% [markdown]
# ### 8-2. Favorite Book
#
# Write a function called `favorite_book()` that accepts one parameter, `title`. The function should print a message, such as *One of my favorite books is Alice in Wonderland.* Call the function, making sure to include a book title as an argument in the function call.

# %%
def favorite_book(title):
    print(f"One of my favorite books is {title}.")

favorite_book("Clean Code")

# %% [markdown]
# ### 8-3. T-Shirt
#
# Write a function called `make_shirt()` that accepts a size and the text of a message that should be printed on the shirt. The function should print a sentence summarizing the size of the shirt and the message printed on it. Call the function once using positional arguments to make a shirt. Call the function a second time using keyword arguments.

# %%
def make_shirt(size, message):
    print(f"Making a {size} shirt with the message: '{message}'")

# Positional arguments
make_shirt("large", "I love Italian food")

# Keyword arguments
make_shirt(message="Rust is safe", size="medium")

# %% [markdown]
# ### 8-4. Large Shirts
#
# Modify the `make_shirt()` function so that shirts are large by default with a message that reads *I love Python.* Make a large shirt and a medium shirt with the default message, and a shirt of any size with a different message.

# %%
def make_shirt(size="large", message="I love Python"):
    print(f"Making a {size} shirt with the message: '{message}'")

# Large shirt with default message
make_shirt()

# Medium shirt with default message
make_shirt(size="medium")

# Any size with different message
make_shirt(size="small", message="Hello World")

# %% [markdown]
# ### 8-5. Cities
#
# Write a function called `describe_city()` that accepts the name of a city and its country. The function should print a simple sentence, such as *Reykjavik is in Iceland.* Give the parameter for the country a default value. Call your function for three different cities, at least one of which is not in the default country.

# %%
def describe_city(city, country="Italy"):
    print(f"{city.title()} is in {country.title()}.")

describe_city("Rome")
describe_city("Athens", "Greece")
describe_city("Miami", "USA")

# %% [markdown]
# ### 8-6. City Names
#
# Write a function called `city_country()` that takes in the name of a city and its country. The function should return a string formatted like this: `"Santiago, Chile"`. Call your function with at least three city-country pairs, and print the values that are returned.

# %%
def city_country(city, country):
    return f"{city.title()}, {country.title()}"

print(city_country("Rome", "Italy"))
print(city_country("Athens", "Greece"))
print(city_country("Miami", "USA"))

# %% [markdown]
# ### 8-7. Album
#
# Write a function called `make_album()` that builds a dictionary describing a music album. The function should take in an artist name and an album title, and it should return a dictionary containing these two pieces of information. Use the function to make three dictionaries representing different albums. Print each return value to show that the dictionaries are storing the album information correctly.
#
# Use `None` to add an optional parameter to `make_album()` that allows you to store the number of songs on an album. If the calling line includes a value for the number of songs, add that value to the album's dictionary. Make at least one new function call that includes the number of songs on an album.

# %%
def make_album(artist, title, songs=None):
    album = {"artist": artist, "title": title}
    if songs is not None:
        album["songs"] = songs
    return album

album1 = make_album("Pink Floyd", "The Dark Side of the Moon")
album2 = make_album("Daft Punk", "Random Access Memories", 13)
album3 = make_album("Queen", "A Night at the Opera", 12)

print(album1)
print(album2)
print(album3)

# %% [markdown]
# ### 8-8. User Albums
#
# Start with your program from Exercise 8-7. Write a `while` loop that allows users to enter an album's artist and title. Once you have that information, call `make_album()` with the user's input and print the dictionary that's created. Be sure to include a quit value in the while loop.

# %%
def make_album(artist, title, songs=None):
    album = {"artist": artist, "title": title}
    if songs is not None:
        album["songs"] = songs
    return album

# Simulated user inputs
inputs = [
    ("Pink Floyd", "The Dark Side of the Moon", 10),
    ("Daft Punk", "Random Access Memories", 13),
    ("quit", "", None)  # Quit signal
]

for artist, title, songs in inputs:
    if artist == "quit":
        print("Goodbye!")
        break
    if songs:
        album = make_album(artist, title, songs)
    else:
        album = make_album(artist, title)
    print(album)

# %% [markdown]
# ### 8-9. Messages
#
# Make a list containing a series of short text messages. Pass the list to a function called `show_messages()`, which prints each text message.

# %%
def show_messages(messages):
    for message in messages:
        print(message)

messages = [
    "Hello! Then state the given task.",
    "Rust is safe and fast.",
    "TypeScript catches bugs early."
]

show_messages(messages)

# %% [markdown]
# ### 8-10. Sending Messages
#
# Start with a copy of your program from Exercise 8-9. Write a function called `send_messages()` that prints each text message and moves each message to a new list called `sent_messages` as it's printed. After calling the function, print both of your lists to make sure the messages were moved correctly.

# %%
def send_messages(messages):
    sent_messages = []
    while messages:
        current_message = messages.pop(0)
        print(current_message)
        sent_messages.append(current_message)
    return sent_messages

messages = [
    "Hello! Then state the given task.",
    "Rust is safe and fast.",
    "TypeScript catches bugs early."
]

sent_messages = send_messages(messages)

print("\nOriginal messages list:", messages)
print("Sent messages list:", sent_messages)

# %% [markdown]
# ### 8-11. Archived Messages
#
# Start with your work from Exercise 8-10. Call the function `send_messages()` with a copy of the list of messages. After calling the function, print both of your lists to show that the original list has retained its messages.

# %%
def send_messages(messages):
    sent_messages = []
    while messages:
        current_message = messages.pop(0)
        print(current_message)
        sent_messages.append(current_message)
    return sent_messages

messages = [
    "Hello! Then state the given task.",
    "Rust is safe and fast.",
    "TypeScript catches bugs early."
]

# Pass a copy using slicing
sent_messages = send_messages(messages[:])

print("\nOriginal messages list:", messages)
print("Sent messages list:", sent_messages)

# %% [markdown]
# ### 8-12. Sandwiches
#
# Write a function that accepts a list of items a person wants on a sandwich. The function should have one parameter that collects as many items as the function call provides, and it should print a summary of the sandwich that's being ordered. Call the function three times, using a different number of arguments each time.

# %%
def make_sandwich(*items):
    print("Making a sandwich with the following items:")
    for item in items:
        print(f"  - {item}")

make_sandwich("prosciutto", "mozzarella", "tomato")
make_sandwich("grilled chicken", "pesto", "arugula")
make_sandwich("meatball", "marinara", "cheese", "onions")

# %% [markdown]
# ### 8-13. User Profile
#
# Start with a copy of `user_profile.py` from page 149. Build a profile of yourself by calling `build_profile()`, using your first and last names and three other key-value pairs that describe you.

# %%
def build_profile(first, last, **user_info):
    user_info["first_name"] = first
    user_info["last_name"] = last
    return user_info

my_profile = build_profile(
    "James",
    "McGuigan",
    age=30,
    city="Queens, New York",
    languages=["TypeScript", "Rust", "Go", "JavaScript"]
)

print(my_profile)

# %% [markdown]
# ### 8-14. Cars
#
# Write a function that stores information about a car in a dictionary. The function should always receive a manufacturer and a model name. It should then accept an arbitrary number of keyword arguments. Call the function with the required information and two other name-value pairs, such as a color or an optional feature. Your function should work for a call like this one:
#
# ```python
# car = make_car('subaru', 'outback', color='blue', tow_package=True)
# ```
#
# Print the dictionary that's returned to make sure all the information was stored correctly.

# %%
def make_car(manufacturer, model, **car_info):
    car = {
        "manufacturer": manufacturer,
        "model": model
    }
    car.update(car_info)
    return car

car = make_car("hyundai", "elantra", color="silver", year=2024)
print(car)

# %% [markdown]
# ### 8-15. Printing Models
#
# Put the functions for the example `printing_models.py` in a separate file called `printing_functions.py`. Write an `import` statement at the top of `printing_models.py`, and modify the file to use the imported functions.
#
# **Note:** In a notebook, we demonstrate the concept inline. In a real project, these would be separate `.py` files.

# %%
# printing_functions.py (normally in its own file)
def print_models(unprinted_designs, completed_models):
    """Simulate printing each design."""
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        print(f"Printing model: {current_design}")
        completed_models.append(current_design)

def show_completed_models(completed_models):
    """Show all completed models."""
    print("\nCompleted models:")
    for model in completed_models:
        print(model)

# printing_models.py would use:
# from printing_functions import print_models, show_completed_models

unprinted = ["Ghost", "Shadow", "Rocket"]
completed = []

print_models(unprinted, completed)
show_completed_models(completed)

# %% [markdown]
# ### 8-16. Imports
#
# Using a program you wrote that has one function in it, store that function in a separate file. Import the function into your main program file, and call the function using each of these approaches:
#
# ```python
# import module_name
# from module_name import function_name
# from module_name import function_name as fn
# import module_name as mn
# from module_name import *
# ```
#
# **Note:** In a notebook, we demonstrate the concept inline.

# %%
# Assuming we have a module called my_functions.py with:
# def greet(name):
#     print(f"Hello, {name}!")

# For demonstration, we'll define it here and show the import patterns
def greet(name):
    print(f"Hello, {name}!")

# import module_name
# import my_functions
# my_functions.greet("Alex")

# from module_name import function_name
# from my_functions import greet
# greet("Sabrina")

# from module_name import function_name as fn
# from my_functions import greet as g
# g("Joe")

# import module_name as mn
# import my_functions as mf
# mf.greet("Andrew")

# from module_name import *
# from my_functions import *
# greet("Chris")

# Direct call for demonstration
greet("Waleed")

# %% [markdown]
# ### 8-17. Styling Functions
#
# Choose any three programs you wrote for this chapter, and make sure they follow the styling guidelines described in this section.
#
# **PEP 8 Guidelines Applied:**
# - Use lowercase with underscores for function names
# - Use docstrings to describe functions
# - Use 2 blank lines before top-level functions
# - Use consistent indentation (4 spaces)
# - Limit line length to 79 characters

# %%
# Example of PEP 8 compliant code from this chapter

def make_shirt(size="large", message="I love Python"):
    """Summarize the shirt being made."""
    print(f"Making a {size} shirt with the message: '{message}'")


def describe_city(city, country="Italy"):
    """Describe a city and its country."""
    print(f"{city.title()} is in {country.title()}.")


def city_country(city, country):
    """Format a city-country pair."""
    return f"{city.title()}, {country.title()}"

# Test the styled functions
make_shirt()
describe_city("Athens", "Greece")
print(city_country("Rome", "Italy"))

# %% [markdown]
# ## Chapter 8 Questions
#
# Add your questions here as you work through the chapter.
