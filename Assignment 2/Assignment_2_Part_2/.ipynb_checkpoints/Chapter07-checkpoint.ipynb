# %% [markdown]
# # Chapter 7: User Input and while Loops

# %% [markdown]
# ### 7-1. Rental Car
#
# Write a program that asks the user what kind of rental car they would like. Print a message about that car, such as *"Let me see if I can find you a Subaru."*

# %%
# Simulating user input for Jupyter
car = "Pagani Huayra"  # input("What kind of rental car would you like? ")
print(f"Let me see if I can find you a {car.title()}.")

# %% [markdown]
# ### 7-2. Restaurant Seating
#
# Write a program that asks the user how many people are in their dinner group. If the answer is more than eight, print a message saying they'll have to wait for a table. Otherwise, report that their table is ready.

# %%
# Test with 6 people (Italian dinner group)
group_size = 6  # int(input("How many people are in your dinner group? "))
if group_size > 8:
    print("You'll have to wait for a table.")
else:
    print("Your table is ready.")

# Test with 10 people
group_size = 10
if group_size > 8:
    print("You'll have to wait for a table.")
else:
    print("Your table is ready.")

# %% [markdown]
# ### 7-3. Multiples of Ten
#
# Ask the user for a number, and then report whether the number is a multiple of 10 or not.

# %%
# Test with 20
number = 20  # int(input("Enter a number: "))
if number % 10 == 0:
    print(f"{number} is a multiple of 10.")
else:
    print(f"{number} is not a multiple of 10.")

# Test with 24
number = 24
if number % 10 == 0:
    print(f"{number} is a multiple of 10.")
else:
    print(f"{number} is not a multiple of 10.")

# %% [markdown]
# ### 7-4. Pizza Toppings
#
# Write a loop that prompts the user to enter a series of pizza toppings until they enter a `'quit'` value. As they enter each topping, print a message saying you'll add that topping to their pizza.

# %%
# Simulating multiple user inputs
toppings = ["pepperoni", "mushrooms", "olives", "onions", "quit"]

for topping in toppings:
    if topping == "quit":
        print("Finished adding toppings.")
        break
    print(f"I'll add {topping} to your pizza.")

# %% [markdown]
# ### 7-5. Movie Tickets
#
# A movie theater charges different ticket prices depending on a person's age. If a person is under the age of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the ticket is $15. Write a loop in which you ask users their age and then tell them the cost of their movie ticket.

# %%
# Simulating multiple ages (teachers and friends)
ages = [25, 28, 30, 32, 35]

for age in ages:
    if age < 3:
        price = 0
    elif age <= 12:
        price = 10
    else:
        price = 15
    print(f"Age {age}: Ticket price is ${price}.")

# %% [markdown]
# ### 7-6. Three Exits
#
# Write different versions of either Exercise 7-4 or Exercise 7-5 that do each of the following at least once:
#
# - Use a conditional test in the `while` statement to stop the loop.
# - Use an active variable to control how long the loop runs.
# - Use a `break` statement to exit the loop when the user enters a `'quit'` value.

# %%
# Version 1: Conditional test in while statement
print("Version 1: Conditional test in while statement")
topping = ""
while topping != "quit":
    topping = "pepperoni"  # Simulating input
    if topping != "quit":
        print(f"I'll add {topping} to your pizza.")
    # In real use: topping = input("Enter a topping (or 'quit'): ")

# Version 2: Active variable controlling loop
print("\nVersion 2: Active variable controlling loop")
active = True
topping = "mushrooms"
while active:
    if topping == "quit":
        active = False
    else:
        print(f"I'll add {topping} to your pizza.")
        topping = "quit"  # Simulating next input

# Version 3: Break statement
print("\nVersion 3: Break statement")
while True:
    topping = "olives"  # Simulating input
    if topping == "quit":
        print("Finished adding toppings.")
        break
    print(f"I'll add {topping} to your pizza.")

# %% [markdown]
# ### 7-7. Infinity
#
# Write a loop that never ends and run it. (To end the loop, press `Ctrl+C` or close the window displaying the output.)
#
# **WARNING:** Do NOT run the infinite loop below in a notebook without understanding how to stop it. Use the kernel interrupt button.

# %%
# WARNING: This is an infinite loop!
# Press the stop button (square) in Jupyter to interrupt it.
# Or press Ctrl+C in terminal.

# Uncomment to run at your own risk:
# while True:
#     print("This loop runs forever!")

# Instead, here's a safe demonstration:
print("Infinite loop demonstration: while True: print('runs forever')")
print("To stop it: press Ctrl+C or use Jupyter's stop button.")

# %% [markdown]
# ### 7-8. Deli
#
# Make a list called `sandwich_orders` and fill it with the names of various sandwiches. Then make an empty list called `finished_sandwiches`. Loop through the list of sandwich orders and print a message for each order, such as *I made your tuna sandwich.* As each sandwich is made, move it to the list of finished sandwiches. After all the sandwiches have been made, print a message listing each sandwich that was made.

# %%
sandwich_orders = [
    "italian sub",
    "chicken parm",
    "meatball",
    "caprese",
    "turkey pesto"
]

finished_sandwiches = []

while sandwich_orders:
    current_sandwich = sandwich_orders.pop(0)
    print(f"I made your {current_sandwich} sandwich.")
    finished_sandwiches.append(current_sandwich)

print("\nAll sandwiches made:")
for sandwich in finished_sandwiches:
    print(f"  - {sandwich}")

# %% [markdown]
# ### 7-9. No Pastrami
#
# Using the list `sandwich_orders` from Exercise 7-8, make sure the sandwich `'pastrami'` appears in the list at least three times. Add code near the beginning of your program to print a message saying the deli has run out of pastrami, and then use a `while` loop to remove all occurrences of `'pastrami'` from `sandwich_orders`. Make sure no pastrami sandwiches end up in `finished_sandwiches`.

# %%
sandwich_orders = [
    "italian sub",
    "pastrami",
    "chicken parm",
    "pastrami",
    "meatball",
    "pastrami",
    "caprese",
    "turkey pesto"
]

finished_sandwiches = []

print("Sorry, the deli has run out of pastrami.")

# Remove all pastrami orders
while "pastrami" in sandwich_orders:
    sandwich_orders.remove("pastrami")

# Make remaining sandwiches
while sandwich_orders:
    current_sandwich = sandwich_orders.pop(0)
    print(f"I made your {current_sandwich} sandwich.")
    finished_sandwiches.append(current_sandwich)

print("\nAll sandwiches made:")
for sandwich in finished_sandwiches:
    print(f"  - {sandwich}")

# %% [markdown]
# ### 7-10. Dream Vacation
#
# Write a program that polls users about their dream vacation. Write a prompt similar to *If you could visit one place in the world, where would you go?* Include a block of code that prints the results of the poll.

# %%
# Simulating poll responses
responses = {}
polling_active = True

names = ["alex", "sabrina", "joe", "andrew"]
places = ["italy", "greece", "florida", "california"]

for name, place in zip(names, places):
    responses[name] = place

print("Poll Results:")
for name, place in responses.items():
    print(f"{name.title()} would like to visit {place.title()}.")

# %% [markdown]
# ## Chapter 7 Questions
#
# Add your questions here as you work through the chapter.
