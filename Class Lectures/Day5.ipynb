# %% [markdown]
# Stacks and heaps with examples for linespace going from 0 to 4
# the memory addess
# knowing it is immuteable meaning if we try rto mutate it we get a brand new integer
# and what a shallow copy is
