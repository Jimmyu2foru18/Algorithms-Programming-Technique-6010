# %% [markdown]
# ## Python Data Types: Dictionary

# %%
dict(zip([1,2,3],['a','b','c']))
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
theDict={}
theDict[1]="a"
print(theDict)
# Out:
# {1: 'a'}

# %% [markdown]
# #### 1. Write a Python script to generate and print a dictionary that contains a number (between 1 and n) in the form (x, x*x)
# * Sample Dictionary ( n = 5) :
# * Expected Output : {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
myN= int(input("input your n for your x:x^2 dict"))
myRange=range(1,myN)
myDict= dict(zip(myRange,[x**2 for x in myRange]))
print(myDict)

#{item:item**2 for item in range(1,5)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
n = int(input("Enter n: "))
{x: x**2 for x in range(1, n+1)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# #### 2. Write a Python program to combine two dictionary adding values for common keys
# * d1 = {'a': 100, 'b': 200, 'c':300}
# * d2 = {'a': 300, 'b': 200, 'd':400}
# * Sample output: Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d3Keys= list(d1.keys())
d3Keys.extend(list(d2.keys()))
#{key: value for item in iterable}
d3={keyVal:d1.get(keyVal,0)+d2.get(keyVal,0) for keyVal in d3Keys}
d3Keys=set(d3) #<--This is your iterable, use the get method on d1 and d2
print(d3)
#{key: value for item in iterable if condition}
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %%
d1 = {'a': 100, 'b': 200, 'c': 300}
d2 = {'a': 300, 'b': 200, 'd': 400}
keys = set(list(d1.keys()) + list(d2.keys()))
{k: d1.get(k,0) + d2.get(k,0) for k in keys}
# Out:
# {'b': 400, 'c': 300, 'a': 400, 'd': 400}

# %% [markdown]
# #### 3. Write a Python program to print all unique values in a dictionary
# * Sample Data : [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
# * Expected Output : Unique Values: {'S005', 'S002', 'S007', 'S001', 'S009'}

# %%
sample = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
result = set()
for d in sample:
    result.update(d.values())
print("Unique Values:", result)
# Out:
# Unique Values: {'S005', 'S001', 'S007', 'S002', 'S009'}

# %% [markdown]
# #### 4. Write a Python program to create and display all combinations of letters, selecting each letter from a different key in a dictionary.
# * Sample data : {'1':['a','b'], '2':['c','d']}
# ###### Expected Output:
# ac
# ad
# bc
# bd

# %%
dict100={'1':['a','b'], '2':['c','d']}

# %%
data = {'1':['a','b'], '2':['c','d']}
keys = list(data.keys())
for a in data[keys[0]]:
    for b in data[keys[1]]:
        print(a+b)
# Out:
# ac
# ad
# bc
# bd

# %% [markdown]
# #### 5. Write a Python program to create a dictionary from a string.
# * Note: Track the count of the letters from the string.
# * Sample string : 'w3resource'
# * Expected output: {'3': 1, 's': 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}

# %%
myString=input("input a string to be made into a dictionary of letters and freq")
{letter:myString.count(letter) for letter in myString}
# Out:
# {'s': 2,
#  't': 3,
#  'r': 2,
#  'i': 1,
#  'n': 1,
#  'g': 1,
#  ' ': 2,
#  'o': 1,
#  'f': 1,
#  'l': 1,
#  'e': 2}

# %%
myString = input("input a string: ")
{letter: myString.count(letter) for letter in myString}
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %% [markdown]
# #### 6. Write a Python program to count the values associated with key in a dictionary.
# * Sample data: = [{'id': 1, 'success': True, 'name': 'Lary'}, {'id': 2, 'success': False, 'name': 'Rabi'}, {'id': 3, 'success': True, 'name': 'Alex'}]
# * Expected result: Count of how many dictionaries have success as True

# %%
data = [{'id': 1, 'success': True, 'name': 'Lary'}, {'id': 2, 'success': False, 'name': 'Rabi'}, {'id': 3, 'success': True, 'name': 'Alex'}]
key = input("Enter key to check: ")
print(sum(1 for d in data if d.get(key) == True))
# Out:
# 0

# %% [markdown]
# #### 7. Write a Python program to convert a list into a nested dictionary of keys.

# %%
my_list = input("Enter items separated by commas: ").split(",")
nested = {}
cur = nested
for item in my_list:
    cur[item.strip()] = {}
    cur = cur[item.strip()]
print(nested)
# Out:
# {'apple': {'orange': {'mango': {'melon': {}}}}}

# %% [markdown]
# #### 8. Write a Python program to sort a list alphabetically in a dictionary.

# %%
data = {'b': ['banana', 'apple'], 'a': ['dog', 'cat']}
result = []
for k in sorted(data.keys()):
    result.append((k, sorted(data[k])))
print(result)
# Out:
# [('a', ['cat', 'dog']), ('b', ['apple', 'banana'])]

# %% [markdown]
# #### 9. Write a Python program to sort Counter by value.
# * Sample data : {'Math':81, 'Physics':83, 'Chemistry':87}
# * Expected data: [('Chemistry', 87), ('Physics', 83), ('Math', 81)]

# %%
data = {'Math': 81, 'Physics': 83, 'Chemistry': 87}
result = sorted(data.items(), key=lambda x: x[1], reverse=True)
print(result)
# Out:
# [('Chemistry', 87), ('Physics', 83), ('Math', 81)]

# %% [markdown]
# #### 10. Write a Python program to match key values in two dictionaries. Go to the editor
# * Sample dictionary: {'key1': 1, 'key2': 3, 'key3': 2}, {'key1': 1, 'key2': 2}
# * Expected output: key1: 1 is present in both x and y

# %%
x = {'key1': 1, 'key2': 3, 'key3': 2}
y = {'key1': 1, 'key2': 2}
for k in x:
    if k in y and x[k] == y[k]:
        print(f"{k}: {x[k]} is present in both x and y")
# Out:
# key1: 1 is present in both x and y
