# %% [markdown]
# ## my first class project

# %%
myList= [12,1,44,55,32,66]
myList2=myList
myList2[0]=23
print(f"here is the firdt element of myList: {myList[0]}")
# Out:
# here is the firdt element of myList: 23

# %%
x=5
y=x
y=23
print(f"x:{x}")
# Out:
# x:5

# %%
import datetime

myDate = datetime.datetime.now().astimezone()
myList = ["Rigby", 66, 42.2, 66, 99.3, "ash", "Rigby", myDate]
print(myList)
# Out:
# ['Rigby', 66, 42.2, 66, 99.3, 'ash', 'Rigby', datetime.datetime(2026, 8, 27, 18, 40, 44, 940043, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000), 'Eastern Daylight Time'))]

# %%
help(datetime.datetime.now())
# Out:
# Help on datetime object:
#
# class datetime(date)
#  |  datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#  |
#  |  The year, month and day arguments are required. tzinfo may be None, or an
#  |  instance of a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  Method resolution order:
#  |      datetime
#  |      date
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
# ...

# %%
emptyList=list()

# %%
myList
# Out:
# ['Rigby', 66, 42.2, 66, 99.3, 'ash', 'Rigby']

# %%
mySet=set(myList)

# %%
mySet
# Out:
# {42.2, 66, 99.3, 'Rigby', 'ash'}

# %%
myTuple=(1,2,3,4)

# %%
myTuple[0]=23
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 myTuple[0]=23
#
# TypeError: 'tuple' object does not support item assignment

# %%
myDict={"ash":1,"rigby":2}

# %%
myDict
# Out:
# {'ash': 1, 'rigby': 2}

# %% [markdown]
# or

# %%
myDict={1:"ash",2:"rigby"}

# %%
myDict
# Out:
# {1: 'ash', 2: 'rigby'}

# %%
x=list(range(0,100,2))

# %%
x[5:14]
# Out:
# [10, 12, 14, 16, 18, 20, 22, 24, 26]

# %%
x[-1]
# Out:
# 98

# %%
x[-1::-1]
# Out:
# [98,
#  96,
#  94,
#  92,
#  90,
#  88,
#  86,
#  84,
#  82,
#  80,
#  78,
#  76,
#  74,
#  72,
#  70,
#  68,
#  66,
#  64,
#  62,
#  60,
#  58,
#  56,
#  54,
#  52,
#  50,
#  48,
#  46,
#  44,
#  42,
#  40,
#  38,
#  36,
#  34,
#  32,
#  30,
#  28,
#  26,
#  24,
#  22,
#  20,
#  18,
#  16,
#  14,
#  12,
#  10,
#  8,
#  6,
#  4,
#  2,
#  0]

# %%
x[len(x)//2]
# Out:
# 50

# %%
x[len(x)//2::]
# Out:
# [50,
#  52,
#  54,
#  56,
#  58,
#  60,
#  62,
#  64,
#  66,
#  68,
#  70,
#  72,
#  74,
#  76,
#  78,
#  80,
#  82,
#  84,
#  86,
#  88,
#  90,
#  92,
#  94,
#  96,
#  98]
